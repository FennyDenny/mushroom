# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %% [markdown]
# There is 8124 rows and 23 columns

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# Here all independent variables are of object type and the target variable is class where classes of mushroom is mentioned.

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# There is no missing values present in the dataset. String data need to be encoded.  It is identified as classification problem.

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# There are 2 unique values in df['class'] that is e and p.

# %%
print(df['class'].value_counts())
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# Here all the frequencies are equally distributed for each classes.

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate Analysis

# %%
sn.countplot(df['class']);

# %% [markdown]
#  All 2 classes are equally distributed so there is no imbalance isssue exists.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1=df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# to view distplot graph, all data converted from strings to numbers

# %%
df1.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# Got first 5 rows from the dataset

# %%
df1.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# Displayed the columns in the dataset

# %%
cor=df1.corr()
cor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# To find the correlation between the variables

# %%
plt.figure(figsize=[30,20])
sn.heatmap(cor,annot=True,linewidths=6,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# gill_size is more relation with the target and here no multicollinearity occurs.
# veil-type is not having any correlation with other variables.

# %%
df1.drop(["veil-type"],axis=1,inplace=True)

# %% [markdown]
# dropped column "veil-type" since there is no correlation with other variables.

# %%
x=df1.drop("class",axis=1)
y=df1["class"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=12)

# %% [markdown]
# creating the train test split

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1245
#            1       1.00      1.00      1.00      1193
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %% [markdown]
# By using DecisionTreeClassifier.  Got the accuracy as 1

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf')#It is a type of kernel we have aligned. Rbf is radial basis function.
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9905660377358491
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1245
#            1       1.00      0.98      0.99      1193
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %% [markdown]
# By using SVC .Got accuracy as 0.99

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(classification_report(y_test,predsvc))
# Out:
# 0.9995898277276456
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1245
#            1       1.00      0.98      0.99      1193
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %% [markdown]
# By using KNeighborsClassifier.  Got accuaracy as 0.999

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1245
#            1       1.00      1.00      1.00      1193
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %% [markdown]
# By using RandomForest Classifier .Got accuracy as 1

# %% [markdown]
# Got the accuracy in RandomForestClassifier and DecisionTreeClassifier as 1 . Got accuracy of SVC and KNN classifiers as 0.99 & 0.999 respectivley.  To check the best accuracy for which model, going to find cross validation score

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score 
print(cross_val_score(dtc,x,y,cv=5).mean())
# Out:
# 0.9074037135278514

# %%
print(cross_val_score(svc,x,y,cv=5).mean())
# Out:
# 0.8420306934444864

# %%
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.8808163698370594

# %%
print(cross_val_score(rfc,x,y,cv=5).mean())
# Out:
# 0.8982952633573322

# %% [markdown]
# Difference between dtc is 9 ,svc is 15, knn is 12 and rfc is 11.  So DecisionTreeClassifier is having best accuracy and its giving the best model also.

# %% [markdown]
# # Hyper parameter tunning

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
parameter={'max_depth':np.arange(2,10),
          'criterion':['gini','entropy'],
          'splitter':['best','random'],
          'max_features':['auto','sqrt','log2']}

# %% [markdown]
# created the parameter list

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 9,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %% [markdown]
# These are the best parameter forms.

# %%
final_model=DecisionTreeClassifier(criterion='gini',max_depth= 9, max_features='sqrt',splitter= 'best')
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
accuracy=accuracy_score(y_test,pred)
print (accuracy*100)
# Out:
# 100.0

# %% [markdown]
# So here got the best model with DecisionTreeClassifier with accuracy 100.  We used the parmeters criterion='gini',max_depth= 9, max_features='sqrt',splitter= 'best'

# %% [markdown]
# # ploltting AOC RUC CURVE

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=dtc.predict_proba(x_test)[:,1]

# %%
fbr,tbr,thresholds=roc_curve(y_test,y_pred_prob) 
plt.plot([0,1],[0,1],'k--') 
plt.plot(fbr,tbr,label="Decision Tree Classifier")
plt.xlabel('False positive rate')
plt.ylabel('true positive rate') 
plt.title('Decision Tree Classifier')
plt.show() 
auc_score=roc_auc_score(y_test,dtc.predict(x_test))
auc_score
# Out:
# 1.0

# %% [markdown]
# plotted the AOC RUC Curve .  Got the accuracy as 1 (100%)

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(final_model,"Final Model of Mushroom.pkl")
# Out:
# ['Final Model of Mushroom.pkl']

# %% [markdown]
# saved the final model
